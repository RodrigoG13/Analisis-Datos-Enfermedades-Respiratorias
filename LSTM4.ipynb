# %% [markdown]
# # PREDICCIÓN DEL CONSUMO DE ENERGÍA USANDO REDES LSTM

# %% [markdown]
# ##  Problema

# %% [markdown]
# Queremos desarrollar un modelo que sea capaz de aprender el patrón de comportamiento en una serie de tiempo (la demanda de Energía Eléctrica) en una región de Estados Unidos, y que posteriormente logre predecir cómo se comportará esta demanda en un futuro cercano.
#
# ![](https://drive.google.com/uc?export=view&id=1UaTeYJVVeHxA2nUX2d9tQIZJ8TiDPEAt)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import RMSprop
import tensorflow as tf
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## El set de datos

# %% [markdown]
# El dataset proviene de una empresa distribuidora de Energía Eléctrica en Estados Unidos (PJM Interconnection LLC), y contiene el comportamiento histórico de la demanda (en MegaWatts) entre los años 2004 y 2018 para la ciudad de Dayton (Ohio). Los registros se realizaron con una periodicidad de 1 hora.

# %%
"""ruta = 'DAYTON_hourly_2004_2018.csv'

# Leer el set de datos
datos = pd.read_csv(ruta, index_col=0, parse_dates=True)
datos.head()"""

import pandas as pd

# Función para cargar y filtrar los datos
def cargar_datos_cluster(ruta_csv, cluster_id):
    # Leer el archivo CSV
    df = pd.read_csv(ruta_csv)
    
    # Configurar la primera columna ('Cluster') como índice
    df.set_index('Cluster', inplace=True)
    
    # Transponer el dataframe para que las fechas sean el índice
    df = df.transpose()
    
    # Filtrar los datos para el cluster específico
    cluster_data = df[cluster_id]
    
    # Resetear el índice para que las fechas sean una columna y no el índice
    cluster_data = cluster_data.reset_index()
    
    # Cambiar los nombres de las columnas
    cluster_data.columns = ['Fecha', 'Contagios']
    
    # Convertir la columna de fecha a tipo datetime para manejarlo como serie temporal
    cluster_data['Fecha'] = pd.to_datetime(cluster_data['Fecha'], format='%d-%m-%Y')
    
    # Establecer la fecha como índice
    cluster_data.set_index('Fecha', inplace=True)
    
    return cluster_data

# Ruta del archivo CSV
ruta_csv = 'clusterSemanal.csv'
# ID del cluster que el usuario quiere explorar
cluster_id = 0  # Cambia esto por un input del usuario si necesario

# Cargar los datos
datos = cargar_datos_cluster(ruta_csv, cluster_id)
datos.head()
# Out:
#             Contagios
# Fecha
# 2020-01-05          9
# 2020-01-12         38
# 2020-01-19         45
# 2020-01-26         37
# 2020-02-02         30

# %% [markdown]
# El set de datos tiene un total de 121,275 registros

# %%
datos.shape
# Out:
# (182, 1)

# %% [markdown]
# Ordenamiento cronológico

# %%
# Y organizar cronológicamente
datos.sort_index(inplace=True)

# %%
sns.set(rc={'figure.figsize':(15, 6)})

# Dibuja los datos de esa columna
datos['Contagios'].plot(linewidth=0.5);

# %% [markdown]
# ## Sets de entrenamiento y prueba

# %% [markdown]
# Como entrada al modelo usaremos bloques de 200 datos consecutivos (`X_train`) y el modelo deberá aprender a predecir el dato 201 de la secuencia (`Y_train`):
#
# ![](https://drive.google.com/uc?export=view&id=1_VqvozHTfjVrzzJzBAII3pIendriES40)

# %%
def dividir_train_test(datos:pd.DataFrame, train_size)-> tuple[pd.DataFrame]:
    idx = round(len(datos)*train_size)
    return idx, datos[0:idx], datos[idx:]

# %%
def crear_set_traint_test(df_train:pd.DataFrame, df_test:pd.DataFrame, long_sec: int) -> tuple[pd.DataFrame]:
    X_train, Y_train = [], []
    for i in range(len(df_train)-long_sec):
        X_train.append(df_train[i:i+long_sec])
        Y_train.append(df_train[i+long_sec])

    X_test, Y_test = [], []
    for i in range(len(df_test)-long_sec):
        X_test.append(df_test[i:i+long_sec])
        Y_test.append(df_test[i+long_sec])

    X_train, Y_train = np.array(X_train), np.array(Y_train)

    # Cambiamos el tamaño a x1 por (ejemplos_train, 200, 1)
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

    X_test, Y_test = np.array(X_test), np.array(Y_test)
    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
    
    return X_train, Y_train, X_test, Y_test

# %%
DATOS = datos['Contagios'].values
TRAIN_SIZE = 0.8

idx, datos_train, datos_test = dividir_train_test(DATOS, TRAIN_SIZE)

# %%
datos_train.reshape(-1,1).shape
# Out:
# (146, 1)

# %%
# Escalemos los datos entre -1 y 1 (por la tanh)
MIN, MAX = -1, 1
scaler = MinMaxScaler(feature_range=(MIN,MAX))
datos_train_s = scaler.fit_transform(datos_train.reshape(-1,1))
datos_test_s = scaler.transform(datos_test.reshape(-1,1))

# %% [markdown]
# Creación del set de entrenaiento y prueba

# %%
LONG_SEC = 14
X_train, Y_train, X_test, Y_test = crear_set_traint_test(datos_train_s, datos_test_s, LONG_SEC)
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)

# 108948 sets de 200 ejemplos cada uno
# Out:
# (132, 14, 1) (132, 1)
# (22, 14, 1) (22, 1)

# %%
ID = 5
print(f'Ejemplo {ID}:')
print(f'   Entrada: {X_train[ID,:,:].T}')
print(f'   Salida: {Y_train[ID]}')
# Out:
# Ejemplo 5:
#    Entrada: [[-0.99762598 -0.99805762 -0.99769792 -0.99705047 -0.99647495 -0.99604331
#   -0.99215856 -0.98438905 -0.98000072 -0.96856228 -0.9474839  -0.93654904
#   -0.9272688  -0.90899608]]
#    Salida: [-0.89619078]

# %%
datos['Contagios'].iloc[0:idx].plot(linewidth=0.5, label='train')
datos['Contagios'].iloc[idx:].plot(linewidth=0.5, color='green', label='test')
plt.legend();

# %% [markdown]
# ## 5 - Creación y entrenamiento del modelo

# %%
# Tamaño del estado oculto y celda de memoria (Similar al tamaño del LONG_SEC)
N_UNITS = 13
modelo = Sequential()
modelo.add(LSTM(N_UNITS, input_shape=(LONG_SEC,1)))
modelo.add(Dense(1))

# %%
optimizador = RMSprop(learning_rate=0.0005)
modelo.compile(optimizer=optimizador, loss='mse', metrics='mean_absolute_error')

# Entrenamiento
EPOCHS = 200
BATCH_SIZE = 10
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

modelo.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=EPOCHS,
           validation_data=(X_test, Y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 14/14 [==============================] - 1s 17ms/step - loss: 0.4205 - mean_absolute_error: 0.5913 - val_loss: 0.6060 - val_mean_absolute_error: 0.7769
# Epoch 2/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2955 - mean_absolute_error: 0.4939 - val_loss: 0.3992 - val_mean_absolute_error: 0.6302
# Epoch 3/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2125 - mean_absolute_error: 0.4179 - val_loss: 0.2408 - val_mean_absolute_error: 0.4889
# Epoch 4/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1602 - mean_absolute_error: 0.3529 - val_loss: 0.1368 - val_mean_absolute_error: 0.3677
# Epoch 5/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1352 - mean_absolute_error: 0.3041 - val_loss: 0.0915 - val_mean_absolute_error: 0.3000
# Epoch 6/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1267 - mean_absolute_error: 0.2811 - val_loss: 0.0587 - val_mean_absolute_error: 0.2393
# Epoch 7/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1210 - mean_absolute_error: 0.2619 - val_loss: 0.0555 - val_mean_absolute_error: 0.2326
# Epoch 8/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1171 - mean_absolute_error: 0.2552 - val_loss: 0.0508 - val_mean_absolute_error: 0.2226
# Epoch 9/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1138 - mean_absolute_error: 0.2493 - val_loss: 0.0515 - val_mean_absolute_error: 0.2241
# Epoch 10/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1097 - mean_absolute_error: 0.2457 - val_loss: 0.0522 - val_mean_absolute_error: 0.2260
# Epoch 11/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1074 - mean_absolute_error: 0.2465 - val_loss: 0.0469 - val_mean_absolute_error: 0.2140
# Epoch 12/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1049 - mean_absolute_error: 0.2401 - val_loss: 0.0456 - val_mean_absolute_error: 0.2111
# Epoch 13/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1025 - mean_absolute_error: 0.2355 - val_loss: 0.0473 - val_mean_absolute_error: 0.2150
# Epoch 14/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0993 - mean_absolute_error: 0.2366 - val_loss: 0.0391 - val_mean_absolute_error: 0.1953
# Epoch 15/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0970 - mean_absolute_error: 0.2274 - val_loss: 0.0289 - val_mean_absolute_error: 0.1674
# Epoch 16/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0945 - mean_absolute_error: 0.2175 - val_loss: 0.0398 - val_mean_absolute_error: 0.1972
# Epoch 17/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0928 - mean_absolute_error: 0.2206 - val_loss: 0.0341 - val_mean_absolute_error: 0.1823
# Epoch 18/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0898 - mean_absolute_error: 0.2154 - val_loss: 0.0392 - val_mean_absolute_error: 0.1958
# Epoch 19/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0874 - mean_absolute_error: 0.2169 - val_loss: 0.0270 - val_mean_absolute_error: 0.1618
# Epoch 20/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0855 - mean_absolute_error: 0.2077 - val_loss: 0.0193 - val_mean_absolute_error: 0.1360
# Epoch 21/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0835 - mean_absolute_error: 0.1949 - val_loss: 0.0294 - val_mean_absolute_error: 0.1691
# Epoch 22/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0816 - mean_absolute_error: 0.1997 - val_loss: 0.0325 - val_mean_absolute_error: 0.1783
# Epoch 23/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0786 - mean_absolute_error: 0.1948 - val_loss: 0.0468 - val_mean_absolute_error: 0.2146
# Epoch 24/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0775 - mean_absolute_error: 0.2047 - val_loss: 0.0284 - val_mean_absolute_error: 0.1663
# Epoch 25/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0752 - mean_absolute_error: 0.1876 - val_loss: 0.0337 - val_mean_absolute_error: 0.1818
# Epoch 26/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0728 - mean_absolute_error: 0.1880 - val_loss: 0.0287 - val_mean_absolute_error: 0.1674
# Epoch 27/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0709 - mean_absolute_error: 0.1796 - val_loss: 0.0348 - val_mean_absolute_error: 0.1847
# Epoch 28/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0692 - mean_absolute_error: 0.1851 - val_loss: 0.0284 - val_mean_absolute_error: 0.1667
# Epoch 29/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0671 - mean_absolute_error: 0.1748 - val_loss: 0.0284 - val_mean_absolute_error: 0.1668
# Epoch 30/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0649 - mean_absolute_error: 0.1736 - val_loss: 0.0255 - val_mean_absolute_error: 0.1579
# Epoch 31/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0633 - mean_absolute_error: 0.1642 - val_loss: 0.0340 - val_mean_absolute_error: 0.1830
# Epoch 32/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0615 - mean_absolute_error: 0.1674 - val_loss: 0.0265 - val_mean_absolute_error: 0.1613
# Epoch 33/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0594 - mean_absolute_error: 0.1622 - val_loss: 0.0175 - val_mean_absolute_error: 0.1306
# Epoch 34/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0584 - mean_absolute_error: 0.1575 - val_loss: 0.0148 - val_mean_absolute_error: 0.1198
# Epoch 35/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0571 - mean_absolute_error: 0.1527 - val_loss: 0.0230 - val_mean_absolute_error: 0.1503
# Epoch 36/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0557 - mean_absolute_error: 0.1515 - val_loss: 0.0215 - val_mean_absolute_error: 0.1450
# Epoch 37/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0540 - mean_absolute_error: 0.1498 - val_loss: 0.0150 - val_mean_absolute_error: 0.1208
# Epoch 38/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0534 - mean_absolute_error: 0.1450 - val_loss: 0.0151 - val_mean_absolute_error: 0.1212
# Epoch 39/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0520 - mean_absolute_error: 0.1423 - val_loss: 0.0239 - val_mean_absolute_error: 0.1534
# Epoch 40/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0510 - mean_absolute_error: 0.1432 - val_loss: 0.0259 - val_mean_absolute_error: 0.1598
# Epoch 41/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0495 - mean_absolute_error: 0.1422 - val_loss: 0.0128 - val_mean_absolute_error: 0.1115
# Epoch 42/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0494 - mean_absolute_error: 0.1363 - val_loss: 0.0103 - val_mean_absolute_error: 0.0999
# Epoch 43/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0487 - mean_absolute_error: 0.1327 - val_loss: 0.0242 - val_mean_absolute_error: 0.1545
# Epoch 44/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0478 - mean_absolute_error: 0.1353 - val_loss: 0.0259 - val_mean_absolute_error: 0.1599
# Epoch 45/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0474 - mean_absolute_error: 0.1375 - val_loss: 0.0109 - val_mean_absolute_error: 0.1030
# Epoch 46/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0463 - mean_absolute_error: 0.1314 - val_loss: 0.0105 - val_mean_absolute_error: 0.1008
# Epoch 47/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0462 - mean_absolute_error: 0.1287 - val_loss: 0.0151 - val_mean_absolute_error: 0.1215
# Epoch 48/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0455 - mean_absolute_error: 0.1292 - val_loss: 0.0111 - val_mean_absolute_error: 0.1038
# Epoch 49/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0436 - mean_absolute_error: 0.1221 - val_loss: 0.0413 - val_mean_absolute_error: 0.2023
# Epoch 50/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0446 - mean_absolute_error: 0.1380 - val_loss: 0.0145 - val_mean_absolute_error: 0.1188
# Epoch 51/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0436 - mean_absolute_error: 0.1277 - val_loss: 0.0176 - val_mean_absolute_error: 0.1314
# Epoch 52/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0431 - mean_absolute_error: 0.1258 - val_loss: 0.0255 - val_mean_absolute_error: 0.1586
# Epoch 53/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0419 - mean_absolute_error: 0.1303 - val_loss: 0.0200 - val_mean_absolute_error: 0.1402
# Epoch 54/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0418 - mean_absolute_error: 0.1237 - val_loss: 0.0245 - val_mean_absolute_error: 0.1556
# Epoch 55/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0412 - mean_absolute_error: 0.1282 - val_loss: 0.0115 - val_mean_absolute_error: 0.1058
# Epoch 56/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0401 - mean_absolute_error: 0.1210 - val_loss: 0.0093 - val_mean_absolute_error: 0.0948
# Epoch 57/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0399 - mean_absolute_error: 0.1211 - val_loss: 0.0057 - val_mean_absolute_error: 0.0732
# Epoch 58/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0386 - mean_absolute_error: 0.1148 - val_loss: 0.0159 - val_mean_absolute_error: 0.1248
# Epoch 59/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0390 - mean_absolute_error: 0.1232 - val_loss: 0.0071 - val_mean_absolute_error: 0.0824
# Epoch 60/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0385 - mean_absolute_error: 0.1176 - val_loss: 0.0146 - val_mean_absolute_error: 0.1197
# Epoch 61/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0384 - mean_absolute_error: 0.1192 - val_loss: 0.0118 - val_mean_absolute_error: 0.1074
# Epoch 62/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0373 - mean_absolute_error: 0.1171 - val_loss: 0.0072 - val_mean_absolute_error: 0.0831
# Epoch 63/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0375 - mean_absolute_error: 0.1169 - val_loss: 0.0120 - val_mean_absolute_error: 0.1084
# Epoch 64/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0365 - mean_absolute_error: 0.1163 - val_loss: 0.0052 - val_mean_absolute_error: 0.0699
# Epoch 65/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0367 - mean_absolute_error: 0.1160 - val_loss: 0.0069 - val_mean_absolute_error: 0.0815
# Epoch 66/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0358 - mean_absolute_error: 0.1109 - val_loss: 0.0144 - val_mean_absolute_error: 0.1190
# Epoch 67/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0358 - mean_absolute_error: 0.1169 - val_loss: 0.0074 - val_mean_absolute_error: 0.0847
# Epoch 68/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0349 - mean_absolute_error: 0.1100 - val_loss: 0.0039 - val_mean_absolute_error: 0.0604
# Epoch 69/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0345 - mean_absolute_error: 0.1092 - val_loss: 0.0080 - val_mean_absolute_error: 0.0879
# Epoch 70/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0337 - mean_absolute_error: 0.1100 - val_loss: 0.0090 - val_mean_absolute_error: 0.0936
# Epoch 71/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0334 - mean_absolute_error: 0.1101 - val_loss: 0.0077 - val_mean_absolute_error: 0.0864
# Epoch 72/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0331 - mean_absolute_error: 0.1077 - val_loss: 0.0068 - val_mean_absolute_error: 0.0809
# Epoch 73/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0330 - mean_absolute_error: 0.1097 - val_loss: 0.0066 - val_mean_absolute_error: 0.0795
# Epoch 74/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0322 - mean_absolute_error: 0.1027 - val_loss: 0.0134 - val_mean_absolute_error: 0.1145
# Epoch 75/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0322 - mean_absolute_error: 0.1112 - val_loss: 0.0067 - val_mean_absolute_error: 0.0802
# Epoch 76/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0318 - mean_absolute_error: 0.1049 - val_loss: 0.0109 - val_mean_absolute_error: 0.1032
# Epoch 77/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0314 - mean_absolute_error: 0.1064 - val_loss: 0.0119 - val_mean_absolute_error: 0.1080
# Epoch 78/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0308 - mean_absolute_error: 0.1065 - val_loss: 0.0133 - val_mean_absolute_error: 0.1140
# Epoch 79/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0305 - mean_absolute_error: 0.1056 - val_loss: 0.0089 - val_mean_absolute_error: 0.0929
# Epoch 80/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0301 - mean_absolute_error: 0.1026 - val_loss: 0.0069 - val_mean_absolute_error: 0.0818
# Epoch 81/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0298 - mean_absolute_error: 0.1025 - val_loss: 0.0055 - val_mean_absolute_error: 0.0721
# Epoch 82/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0294 - mean_absolute_error: 0.1034 - val_loss: 0.0067 - val_mean_absolute_error: 0.0802
# Epoch 83/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0291 - mean_absolute_error: 0.1020 - val_loss: 0.0032 - val_mean_absolute_error: 0.0548
# Epoch 84/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0291 - mean_absolute_error: 0.0985 - val_loss: 0.0095 - val_mean_absolute_error: 0.0959
# Epoch 85/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0283 - mean_absolute_error: 0.1003 - val_loss: 0.0074 - val_mean_absolute_error: 0.0847
# Epoch 86/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0279 - mean_absolute_error: 0.0997 - val_loss: 0.0044 - val_mean_absolute_error: 0.0645
# Epoch 87/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0274 - mean_absolute_error: 0.0951 - val_loss: 0.0136 - val_mean_absolute_error: 0.1155
# Epoch 88/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0274 - mean_absolute_error: 0.1014 - val_loss: 0.0097 - val_mean_absolute_error: 0.0971
# Epoch 89/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0271 - mean_absolute_error: 0.0984 - val_loss: 0.0045 - val_mean_absolute_error: 0.0655
# Epoch 90/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0265 - mean_absolute_error: 0.0958 - val_loss: 0.0068 - val_mean_absolute_error: 0.0812
# Epoch 91/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0265 - mean_absolute_error: 0.0968 - val_loss: 0.0029 - val_mean_absolute_error: 0.0513
# Epoch 92/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0263 - mean_absolute_error: 0.0936 - val_loss: 0.0105 - val_mean_absolute_error: 0.1011
# Epoch 93/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0261 - mean_absolute_error: 0.0981 - val_loss: 0.0058 - val_mean_absolute_error: 0.0744
# Epoch 94/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0254 - mean_absolute_error: 0.0925 - val_loss: 0.0100 - val_mean_absolute_error: 0.0987
# Epoch 95/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0252 - mean_absolute_error: 0.0961 - val_loss: 9.9642e-04 - val_mean_absolute_error: 0.0278
# Epoch 96/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0253 - mean_absolute_error: 0.0903 - val_loss: 0.0084 - val_mean_absolute_error: 0.0903
# Epoch 97/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0253 - mean_absolute_error: 0.0933 - val_loss: 0.0049 - val_mean_absolute_error: 0.0680
# Epoch 98/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0248 - mean_absolute_error: 0.0940 - val_loss: 0.0030 - val_mean_absolute_error: 0.0529
# Epoch 99/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0244 - mean_absolute_error: 0.0917 - val_loss: 0.0028 - val_mean_absolute_error: 0.0506
# Epoch 100/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0240 - mean_absolute_error: 0.0913 - val_loss: 0.0020 - val_mean_absolute_error: 0.0422
# Epoch 101/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0241 - mean_absolute_error: 0.0892 - val_loss: 0.0064 - val_mean_absolute_error: 0.0783
# Epoch 102/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0233 - mean_absolute_error: 0.0893 - val_loss: 0.0173 - val_mean_absolute_error: 0.1308
# Epoch 103/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0234 - mean_absolute_error: 0.0956 - val_loss: 0.0015 - val_mean_absolute_error: 0.0352
# Epoch 104/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0234 - mean_absolute_error: 0.0900 - val_loss: 0.0022 - val_mean_absolute_error: 0.0442
# Epoch 105/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0229 - mean_absolute_error: 0.0927 - val_loss: 0.0021 - val_mean_absolute_error: 0.0434
# Epoch 106/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0230 - mean_absolute_error: 0.0886 - val_loss: 0.0026 - val_mean_absolute_error: 0.0492
# Epoch 107/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0226 - mean_absolute_error: 0.0879 - val_loss: 0.0019 - val_mean_absolute_error: 0.0411
# Epoch 108/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0224 - mean_absolute_error: 0.0862 - val_loss: 0.0050 - val_mean_absolute_error: 0.0693
# Epoch 109/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0219 - mean_absolute_error: 0.0877 - val_loss: 0.0073 - val_mean_absolute_error: 0.0843
# Epoch 110/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0219 - mean_absolute_error: 0.0873 - val_loss: 0.0048 - val_mean_absolute_error: 0.0672
# Epoch 111/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0214 - mean_absolute_error: 0.0866 - val_loss: 0.0020 - val_mean_absolute_error: 0.0422
# Epoch 112/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0215 - mean_absolute_error: 0.0865 - val_loss: 0.0032 - val_mean_absolute_error: 0.0542
# Epoch 113/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0210 - mean_absolute_error: 0.0867 - val_loss: 0.0034 - val_mean_absolute_error: 0.0566
# Epoch 114/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0208 - mean_absolute_error: 0.0834 - val_loss: 0.0055 - val_mean_absolute_error: 0.0728
# Epoch 115/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0210 - mean_absolute_error: 0.0856 - val_loss: 0.0029 - val_mean_absolute_error: 0.0519
# Epoch 116/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0207 - mean_absolute_error: 0.0839 - val_loss: 0.0027 - val_mean_absolute_error: 0.0502
# Epoch 117/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0201 - mean_absolute_error: 0.0839 - val_loss: 0.0025 - val_mean_absolute_error: 0.0480
# Epoch 118/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0198 - mean_absolute_error: 0.0799 - val_loss: 0.0146 - val_mean_absolute_error: 0.1198
# Epoch 119/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0205 - mean_absolute_error: 0.0934 - val_loss: 0.0030 - val_mean_absolute_error: 0.0522
# Epoch 120/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0197 - mean_absolute_error: 0.0824 - val_loss: 0.0026 - val_mean_absolute_error: 0.0491
# Epoch 121/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0190 - mean_absolute_error: 0.0776 - val_loss: 0.0043 - val_mean_absolute_error: 0.0640
# Epoch 122/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0193 - mean_absolute_error: 0.0799 - val_loss: 0.0053 - val_mean_absolute_error: 0.0712
# Epoch 123/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0193 - mean_absolute_error: 0.0818 - val_loss: 0.0012 - val_mean_absolute_error: 0.0303
# Epoch 124/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0190 - mean_absolute_error: 0.0807 - val_loss: 0.0016 - val_mean_absolute_error: 0.0371
# Epoch 125/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0188 - mean_absolute_error: 0.0794 - val_loss: 7.2539e-04 - val_mean_absolute_error: 0.0223
# Epoch 126/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0188 - mean_absolute_error: 0.0787 - val_loss: 0.0014 - val_mean_absolute_error: 0.0337
# Epoch 127/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0186 - mean_absolute_error: 0.0778 - val_loss: 0.0098 - val_mean_absolute_error: 0.0977
# Epoch 128/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0188 - mean_absolute_error: 0.0846 - val_loss: 8.7589e-04 - val_mean_absolute_error: 0.0252
# Epoch 129/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0186 - mean_absolute_error: 0.0784 - val_loss: 0.0026 - val_mean_absolute_error: 0.0490
# Epoch 130/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0180 - mean_absolute_error: 0.0782 - val_loss: 5.1510e-04 - val_mean_absolute_error: 0.0177
# Epoch 131/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0184 - mean_absolute_error: 0.0775 - val_loss: 0.0017 - val_mean_absolute_error: 0.0378
# Epoch 132/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0179 - mean_absolute_error: 0.0773 - val_loss: 0.0027 - val_mean_absolute_error: 0.0495
# Epoch 133/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0180 - mean_absolute_error: 0.0777 - val_loss: 0.0017 - val_mean_absolute_error: 0.0383
# Epoch 134/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0175 - mean_absolute_error: 0.0762 - val_loss: 0.0053 - val_mean_absolute_error: 0.0714
# Epoch 135/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0172 - mean_absolute_error: 0.0781 - val_loss: 4.0423e-04 - val_mean_absolute_error: 0.0147
# Epoch 136/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0171 - mean_absolute_error: 0.0755 - val_loss: 2.5434e-04 - val_mean_absolute_error: 0.0105
# Epoch 137/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0167 - mean_absolute_error: 0.0731 - val_loss: 0.0024 - val_mean_absolute_error: 0.0468
# Epoch 138/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0168 - mean_absolute_error: 0.0754 - val_loss: 0.0011 - val_mean_absolute_error: 0.0299
# Epoch 139/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0170 - mean_absolute_error: 0.0755 - val_loss: 2.9409e-04 - val_mean_absolute_error: 0.0116
# Epoch 140/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0167 - mean_absolute_error: 0.0742 - val_loss: 0.0050 - val_mean_absolute_error: 0.0692
# Epoch 141/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0164 - mean_absolute_error: 0.0779 - val_loss: 0.0015 - val_mean_absolute_error: 0.0349
# Epoch 142/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0164 - mean_absolute_error: 0.0734 - val_loss: 7.7688e-04 - val_mean_absolute_error: 0.0232
# Epoch 143/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0164 - mean_absolute_error: 0.0723 - val_loss: 7.6102e-04 - val_mean_absolute_error: 0.0229
# Epoch 144/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0164 - mean_absolute_error: 0.0720 - val_loss: 0.0083 - val_mean_absolute_error: 0.0899
# Epoch 145/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0159 - mean_absolute_error: 0.0752 - val_loss: 0.0018 - val_mean_absolute_error: 0.0394
# Epoch 146/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0158 - mean_absolute_error: 0.0734 - val_loss: 0.0070 - val_mean_absolute_error: 0.0821
# Epoch 147/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0157 - mean_absolute_error: 0.0751 - val_loss: 5.7177e-04 - val_mean_absolute_error: 0.0190
# Epoch 148/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0159 - mean_absolute_error: 0.0722 - val_loss: 2.9855e-04 - val_mean_absolute_error: 0.0116
# Epoch 149/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0157 - mean_absolute_error: 0.0725 - val_loss: 0.0010 - val_mean_absolute_error: 0.0278
# Epoch 150/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0153 - mean_absolute_error: 0.0708 - val_loss: 0.0019 - val_mean_absolute_error: 0.0402
# Epoch 151/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0152 - mean_absolute_error: 0.0696 - val_loss: 0.0059 - val_mean_absolute_error: 0.0751
# Epoch 152/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0151 - mean_absolute_error: 0.0744 - val_loss: 0.0016 - val_mean_absolute_error: 0.0363
# Epoch 153/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0149 - mean_absolute_error: 0.0705 - val_loss: 0.0017 - val_mean_absolute_error: 0.0373
# Epoch 154/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0152 - mean_absolute_error: 0.0704 - val_loss: 0.0017 - val_mean_absolute_error: 0.0378
# Epoch 155/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0148 - mean_absolute_error: 0.0709 - val_loss: 0.0017 - val_mean_absolute_error: 0.0374
# Epoch 156/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0145 - mean_absolute_error: 0.0691 - val_loss: 0.0049 - val_mean_absolute_error: 0.0683
# Epoch 157/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0148 - mean_absolute_error: 0.0701 - val_loss: 0.0011 - val_mean_absolute_error: 0.0286
# Epoch 158/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0144 - mean_absolute_error: 0.0686 - val_loss: 0.0013 - val_mean_absolute_error: 0.0323
# Epoch 159/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0147 - mean_absolute_error: 0.0715 - val_loss: 9.0680e-04 - val_mean_absolute_error: 0.0257
# Epoch 160/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0146 - mean_absolute_error: 0.0698 - val_loss: 0.0015 - val_mean_absolute_error: 0.0347
# Epoch 161/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0144 - mean_absolute_error: 0.0681 - val_loss: 0.0014 - val_mean_absolute_error: 0.0337
# Epoch 162/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0142 - mean_absolute_error: 0.0696 - val_loss: 0.0018 - val_mean_absolute_error: 0.0390
# Epoch 163/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0141 - mean_absolute_error: 0.0678 - val_loss: 0.0024 - val_mean_absolute_error: 0.0462
# Epoch 164/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0137 - mean_absolute_error: 0.0660 - val_loss: 0.0078 - val_mean_absolute_error: 0.0866
# Epoch 165/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0136 - mean_absolute_error: 0.0714 - val_loss: 9.0988e-04 - val_mean_absolute_error: 0.0256
# Epoch 166/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0140 - mean_absolute_error: 0.0685 - val_loss: 0.0014 - val_mean_absolute_error: 0.0340

# %% [markdown]
# ##  Predicción

# %% [markdown]
# Verifiquemos inicialmente qué tan bien se genera la predicción sobre cada dato de prueba en `X_test`:

# %%
# Predicción (1 muestra, single-step)
y_pred = [y[0] for y in modelo.predict(X_test)]
y_pred = np.array(y_pred)
print(X_test.shape)
print(len(y_pred))
# Out:
# 1/1 [==============================] - 0s 162ms/step
# (22, 14, 1)
# 22

# %%
# Predicciones en la escala original
y_test_inv = scaler.inverse_transform(Y_test)

y_pred_inv = y_pred.reshape(-1,1)
y_pred_inv = scaler.inverse_transform(y_pred_inv)

plt.figure(figsize=(12,4))
plt.plot(y_test_inv[0:500],color='blue',label='test')
plt.plot(y_pred_inv[0:500],color='orange',label='predicción')
plt.legend();

# %%
# Gráfica del error absoluto
plt.figure(figsize=(12,4))
plt.plot(np.abs(y_test_inv-y_pred_inv), color='red');
plt.ylabel('Error absoluto (en Watts)');

# %%
modelo.save('modelo1.h5')  # Guarda el modelo en formato HDF5
# Out:
# /usr/lib/python3/dist-packages/keras/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# Ahora haremos predicción *multi-step*: en lugar de predecir un sólo dato vamos a predecir una secuencia completa:

# %%
# Tomar la primera parte de X_test como punto de inicio
x_pred = X_test[0,:,:].reshape(1,LONG_SEC,1)

# Iterativamente predecir y201 = pred(x1,x2,...,x200),
# y202 = pred(x2, x3, x4,..., x200, y201), etc...

N_preds = 100
y_preds = []    

for i in range(N_preds):

  pred = modelo.predict(x_pred)
  y_preds.append(pred[0])

  x_pred = np.append(x_pred,pred[0])

  x_pred = np.delete(x_pred,0)

  x_pred = np.reshape(x_pred,(1,LONG_SEC,1))
# Out:
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step

# %%
# Regresamos las predicciones en la escala original
y_preds = np.array(y_preds).reshape(-1,1)
y_preds = scaler.inverse_transform(y_preds)

# Comparación gráfica con el set de prueba original
plt.figure(figsize=(12,4))
plt.plot(y_test_inv[0:N_preds],color='blue',label='test')
plt.plot(y_preds[0:N_preds],color='orange',label='predicción multi-step')
plt.legend();

# %%
HRS = 10
plt.figure(figsize=(12,4))
plt.plot(range(1,HRS+1),y_test_inv[0:HRS],color='blue',label='test')
plt.plot(range(1,HRS+1),y_preds[0:HRS],color='orange',label='predicción multi-step')
plt.legend();
