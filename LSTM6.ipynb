# %% [markdown]
# # PREDICCIÓN DEL CONSUMO DE ENERGÍA USANDO REDES LSTM

# %% [markdown]
# ##  Problema

# %% [markdown]
# Queremos desarrollar un modelo que sea capaz de aprender el patrón de comportamiento en una serie de tiempo (la demanda de Energía Eléctrica) en una región de Estados Unidos, y que posteriormente logre predecir cómo se comportará esta demanda en un futuro cercano.
#
# ![](https://drive.google.com/uc?export=view&id=1UaTeYJVVeHxA2nUX2d9tQIZJ8TiDPEAt)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import RMSprop
import tensorflow as tf
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import LeakyReLU

# %% [markdown]
# ## El set de datos

# %% [markdown]
# El dataset proviene de una empresa distribuidora de Energía Eléctrica en Estados Unidos (PJM Interconnection LLC), y contiene el comportamiento histórico de la demanda (en MegaWatts) entre los años 2004 y 2018 para la ciudad de Dayton (Ohio). Los registros se realizaron con una periodicidad de 1 hora.

# %%
"""ruta = 'DAYTON_hourly_2004_2018.csv'

# Leer el set de datos
datos = pd.read_csv(ruta, index_col=0, parse_dates=True)
datos.head()"""

import pandas as pd

# Función para cargar y filtrar los datos
def cargar_datos_cluster(ruta_csv, cluster_id):
    # Leer el archivo CSV
    df = pd.read_csv(ruta_csv)
    
    # Configurar la primera columna ('Cluster') como índice
    df.set_index('Cluster', inplace=True)
    
    # Transponer el dataframe para que las fechas sean el índice
    df = df.transpose()
    
    # Filtrar los datos para el cluster específico
    cluster_data = df[cluster_id]
    
    # Resetear el índice para que las fechas sean una columna y no el índice
    cluster_data = cluster_data.reset_index()
    
    # Cambiar los nombres de las columnas
    cluster_data.columns = ['Fecha', 'Contagios']
    
    # Convertir la columna de fecha a tipo datetime para manejarlo como serie temporal
    cluster_data['Fecha'] = pd.to_datetime(cluster_data['Fecha'], format='%d-%m-%Y')
    
    # Establecer la fecha como índice
    cluster_data.set_index('Fecha', inplace=True)
    
    return cluster_data

# Ruta del archivo CSV
ruta_csv = 'clusterSemanal.csv'
# ID del cluster que el usuario quiere explorar
cluster_id = 0  # Cambia esto por un input del usuario si necesario

# Cargar los datos
datos = cargar_datos_cluster(ruta_csv, cluster_id)
datos.head()
# Out:
#             Contagios
# Fecha
# 2020-01-05          9
# 2020-01-12         38
# 2020-01-19         45
# 2020-01-26         37
# 2020-02-02         30

# %% [markdown]
# El set de datos tiene un total de 121,275 registros

# %%
datos.shape
# Out:
# (182, 1)

# %% [markdown]
# Ordenamiento cronológico

# %%
# Y organizar cronológicamente
datos.sort_index(inplace=True)

# %%
sns.set(rc={'figure.figsize':(15, 6)})

# Dibuja los datos de esa columna
datos['Contagios'].plot(linewidth=0.5);

# %% [markdown]
# ## Sets de entrenamiento y prueba

# %% [markdown]
# Como entrada al modelo usaremos bloques de 200 datos consecutivos (`X_train`) y el modelo deberá aprender a predecir el dato 201 de la secuencia (`Y_train`):
#
# ![](https://drive.google.com/uc?export=view&id=1_VqvozHTfjVrzzJzBAII3pIendriES40)

# %%
def dividir_train_test(datos:pd.DataFrame, train_size)-> tuple[pd.DataFrame]:
    idx = round(len(datos)*train_size)
    return idx, datos[0:idx], datos[idx:]

# %%
def crear_set_traint_test(df_train:pd.DataFrame, df_test:pd.DataFrame, long_sec: int) -> tuple[pd.DataFrame]:
    X_train, Y_train = [], []
    for i in range(len(df_train)-long_sec):
        X_train.append(df_train[i:i+long_sec])
        Y_train.append(df_train[i+long_sec])

    X_test, Y_test = [], []
    for i in range(len(df_test)-long_sec):
        X_test.append(df_test[i:i+long_sec])
        Y_test.append(df_test[i+long_sec])

    X_train, Y_train = np.array(X_train), np.array(Y_train)

    # Cambiamos el tamaño a x1 por (ejemplos_train, 200, 1)
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

    X_test, Y_test = np.array(X_test), np.array(Y_test)
    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
    
    return X_train, Y_train, X_test, Y_test

# %%
DATOS = datos['Contagios'].values
TRAIN_SIZE = 0.8

idx, datos_train, datos_test = dividir_train_test(DATOS, TRAIN_SIZE)

# %%
datos_train.reshape(-1,1).shape
# Out:
# (146, 1)

# %%
# Escalemos los datos entre -1 y 1 (por la tanh)
MIN, MAX = -1, 1
scaler = MinMaxScaler(feature_range=(MIN,MAX))
datos_train_s = scaler.fit_transform(datos_train.reshape(-1,1))
datos_test_s = scaler.transform(datos_test.reshape(-1,1))

# %% [markdown]
# Creación del set de entrenaiento y prueba

# %%
LONG_SEC = 14
X_train, Y_train, X_test, Y_test = crear_set_traint_test(datos_train_s, datos_test_s, LONG_SEC)
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)

# 108948 sets de 200 ejemplos cada uno
# Out:
# (132, 14, 1) (132, 1)
# (22, 14, 1) (22, 1)

# %%
ID = 5
print(f'Ejemplo {ID}:')
print(f'   Entrada: {X_train[ID,:,:].T}')
print(f'   Salida: {Y_train[ID]}')
# Out:
# Ejemplo 5:
#    Entrada: [[-0.99762598 -0.99805762 -0.99769792 -0.99705047 -0.99647495 -0.99604331
#   -0.99215856 -0.98438905 -0.98000072 -0.96856228 -0.9474839  -0.93654904
#   -0.9272688  -0.90899608]]
#    Salida: [-0.89619078]

# %%
datos['Contagios'].iloc[0:idx].plot(linewidth=0.5, label='train')
datos['Contagios'].iloc[idx:].plot(linewidth=0.5, color='green', label='test')
plt.legend();

# %% [markdown]
# ## 5 - Creación y entrenamiento del modelo

# %%
# Tamaño del estado oculto y celda de memoria (Similar al tamaño del LONG_SEC)
N_UNITS = 13
modelo = Sequential()
modelo.add(LSTM(N_UNITS, input_shape=(LONG_SEC, 1)))
modelo.add(Dense(50))
modelo.add(LeakyReLU(alpha=0.01))
modelo.add(Dropout(0.20))  # Opcional: Dropout para regularización
modelo.add(Dense(20))  # Segunda capa densa adicional
modelo.add(LeakyReLU(alpha=0.01))
modelo.add(Dense(1))  # Capa de salida

# %%
optimizador = RMSprop(learning_rate=0.0005)
modelo.compile(optimizer=optimizador, loss='mse', metrics='mean_absolute_error')

# Entrenamiento
EPOCHS = 250
BATCH_SIZE = 10
early_stopping = EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True)

modelo.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=EPOCHS,
           validation_data=(X_test, Y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/250
# 14/14 [==============================] - 1s 19ms/step - loss: 0.3513 - mean_absolute_error: 0.5390 - val_loss: 0.4476 - val_mean_absolute_error: 0.6675
# Epoch 2/250
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1959 - mean_absolute_error: 0.3998 - val_loss: 0.1953 - val_mean_absolute_error: 0.4401
# Epoch 3/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1193 - mean_absolute_error: 0.2948 - val_loss: 0.0758 - val_mean_absolute_error: 0.2733
# Epoch 4/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0939 - mean_absolute_error: 0.2332 - val_loss: 0.0173 - val_mean_absolute_error: 0.1279
# Epoch 5/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0885 - mean_absolute_error: 0.2102 - val_loss: 0.0327 - val_mean_absolute_error: 0.1783
# Epoch 6/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0859 - mean_absolute_error: 0.2031 - val_loss: 0.0319 - val_mean_absolute_error: 0.1761
# Epoch 7/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0837 - mean_absolute_error: 0.2066 - val_loss: 0.0192 - val_mean_absolute_error: 0.1357
# Epoch 8/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0804 - mean_absolute_error: 0.1920 - val_loss: 0.0499 - val_mean_absolute_error: 0.2216
# Epoch 9/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0748 - mean_absolute_error: 0.2002 - val_loss: 0.0153 - val_mean_absolute_error: 0.1208
# Epoch 10/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0802 - mean_absolute_error: 0.2016 - val_loss: 0.0101 - val_mean_absolute_error: 0.0974
# Epoch 11/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0766 - mean_absolute_error: 0.1897 - val_loss: 0.0063 - val_mean_absolute_error: 0.0755
# Epoch 12/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0773 - mean_absolute_error: 0.1795 - val_loss: 0.0172 - val_mean_absolute_error: 0.1289
# Epoch 13/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0671 - mean_absolute_error: 0.1805 - val_loss: 0.0119 - val_mean_absolute_error: 0.1065
# Epoch 14/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0733 - mean_absolute_error: 0.1821 - val_loss: 0.0147 - val_mean_absolute_error: 0.1191
# Epoch 15/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0652 - mean_absolute_error: 0.1701 - val_loss: 0.0061 - val_mean_absolute_error: 0.0756
# Epoch 16/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0670 - mean_absolute_error: 0.1774 - val_loss: 0.0094 - val_mean_absolute_error: 0.0944
# Epoch 17/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0618 - mean_absolute_error: 0.1608 - val_loss: 0.0120 - val_mean_absolute_error: 0.1076
# Epoch 18/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0627 - mean_absolute_error: 0.1724 - val_loss: 0.0090 - val_mean_absolute_error: 0.0930
# Epoch 19/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0627 - mean_absolute_error: 0.1620 - val_loss: 0.0280 - val_mean_absolute_error: 0.1660
# Epoch 20/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0586 - mean_absolute_error: 0.1569 - val_loss: 0.0113 - val_mean_absolute_error: 0.1047
# Epoch 21/250
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0539 - mean_absolute_error: 0.1521 - val_loss: 0.0169 - val_mean_absolute_error: 0.1285
# Epoch 22/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0583 - mean_absolute_error: 0.1563 - val_loss: 0.0307 - val_mean_absolute_error: 0.1740
# Epoch 23/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0560 - mean_absolute_error: 0.1561 - val_loss: 0.0228 - val_mean_absolute_error: 0.1497
# Epoch 24/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0511 - mean_absolute_error: 0.1496 - val_loss: 0.0034 - val_mean_absolute_error: 0.0558
# Epoch 25/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0514 - mean_absolute_error: 0.1477 - val_loss: 0.0012 - val_mean_absolute_error: 0.0295
# Epoch 26/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0552 - mean_absolute_error: 0.1499 - val_loss: 0.0053 - val_mean_absolute_error: 0.0704
# Epoch 27/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0525 - mean_absolute_error: 0.1447 - val_loss: 0.0251 - val_mean_absolute_error: 0.1571
# Epoch 28/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0531 - mean_absolute_error: 0.1548 - val_loss: 0.0127 - val_mean_absolute_error: 0.1112
# Epoch 29/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0547 - mean_absolute_error: 0.1516 - val_loss: 0.0034 - val_mean_absolute_error: 0.0554
# Epoch 30/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0486 - mean_absolute_error: 0.1374 - val_loss: 0.0227 - val_mean_absolute_error: 0.1496
# Epoch 31/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0467 - mean_absolute_error: 0.1349 - val_loss: 0.0049 - val_mean_absolute_error: 0.0672
# Epoch 32/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0474 - mean_absolute_error: 0.1342 - val_loss: 0.0216 - val_mean_absolute_error: 0.1459
# Epoch 33/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0461 - mean_absolute_error: 0.1313 - val_loss: 0.0047 - val_mean_absolute_error: 0.0661
# Epoch 34/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0456 - mean_absolute_error: 0.1385 - val_loss: 0.0276 - val_mean_absolute_error: 0.1652
# Epoch 35/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0464 - mean_absolute_error: 0.1402 - val_loss: 0.0283 - val_mean_absolute_error: 0.1671
# Epoch 36/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0438 - mean_absolute_error: 0.1370 - val_loss: 0.0104 - val_mean_absolute_error: 0.1004
# Epoch 37/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0439 - mean_absolute_error: 0.1365 - val_loss: 0.0104 - val_mean_absolute_error: 0.1004
# Epoch 38/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0441 - mean_absolute_error: 0.1366 - val_loss: 0.0037 - val_mean_absolute_error: 0.0586
# Epoch 39/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0462 - mean_absolute_error: 0.1374 - val_loss: 0.0053 - val_mean_absolute_error: 0.0703
# Epoch 40/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0442 - mean_absolute_error: 0.1355 - val_loss: 0.0031 - val_mean_absolute_error: 0.0528
# Epoch 41/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0419 - mean_absolute_error: 0.1342 - val_loss: 0.0170 - val_mean_absolute_error: 0.1293
# Epoch 42/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0408 - mean_absolute_error: 0.1359 - val_loss: 0.0042 - val_mean_absolute_error: 0.0629
# Epoch 43/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0424 - mean_absolute_error: 0.1264 - val_loss: 0.0438 - val_mean_absolute_error: 0.2084
# Epoch 44/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0425 - mean_absolute_error: 0.1391 - val_loss: 0.0123 - val_mean_absolute_error: 0.1096
# Epoch 45/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0434 - mean_absolute_error: 0.1332 - val_loss: 0.0016 - val_mean_absolute_error: 0.0362
# Epoch 46/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0404 - mean_absolute_error: 0.1333 - val_loss: 0.0016 - val_mean_absolute_error: 0.0367
# Epoch 47/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0407 - mean_absolute_error: 0.1229 - val_loss: 0.0022 - val_mean_absolute_error: 0.0435
# Epoch 48/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0424 - mean_absolute_error: 0.1311 - val_loss: 0.0055 - val_mean_absolute_error: 0.0718
# Epoch 49/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0392 - mean_absolute_error: 0.1260 - val_loss: 0.0151 - val_mean_absolute_error: 0.1216
# Epoch 50/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0395 - mean_absolute_error: 0.1325 - val_loss: 0.0065 - val_mean_absolute_error: 0.0787
# Epoch 51/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0381 - mean_absolute_error: 0.1230 - val_loss: 0.0078 - val_mean_absolute_error: 0.0864
# Epoch 52/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0411 - mean_absolute_error: 0.1322 - val_loss: 0.0068 - val_mean_absolute_error: 0.0806
# Epoch 53/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0375 - mean_absolute_error: 0.1203 - val_loss: 0.0129 - val_mean_absolute_error: 0.1123
# Epoch 54/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0358 - mean_absolute_error: 0.1243 - val_loss: 0.0177 - val_mean_absolute_error: 0.1322
# Epoch 55/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0340 - mean_absolute_error: 0.1217 - val_loss: 0.0050 - val_mean_absolute_error: 0.0690
# Epoch 56/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0365 - mean_absolute_error: 0.1173 - val_loss: 0.0088 - val_mean_absolute_error: 0.0926
# Epoch 57/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0366 - mean_absolute_error: 0.1246 - val_loss: 0.0022 - val_mean_absolute_error: 0.0438
# Epoch 58/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0367 - mean_absolute_error: 0.1271 - val_loss: 0.0121 - val_mean_absolute_error: 0.1089
# Epoch 59/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0359 - mean_absolute_error: 0.1190 - val_loss: 0.0084 - val_mean_absolute_error: 0.0901
# Epoch 60/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0364 - mean_absolute_error: 0.1288 - val_loss: 4.2225e-04 - val_mean_absolute_error: 0.0171
# Epoch 61/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0322 - mean_absolute_error: 0.1147 - val_loss: 0.0058 - val_mean_absolute_error: 0.0740
# Epoch 62/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0322 - mean_absolute_error: 0.1144 - val_loss: 4.9325e-04 - val_mean_absolute_error: 0.0173
# Epoch 63/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0339 - mean_absolute_error: 0.1166 - val_loss: 0.0024 - val_mean_absolute_error: 0.0463
# Epoch 64/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0347 - mean_absolute_error: 0.1154 - val_loss: 0.0095 - val_mean_absolute_error: 0.0960
# Epoch 65/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0312 - mean_absolute_error: 0.1125 - val_loss: 0.0079 - val_mean_absolute_error: 0.0873
# Epoch 66/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0331 - mean_absolute_error: 0.1167 - val_loss: 0.0135 - val_mean_absolute_error: 0.1149
# Epoch 67/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0348 - mean_absolute_error: 0.1230 - val_loss: 0.0021 - val_mean_absolute_error: 0.0424
# Epoch 68/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0351 - mean_absolute_error: 0.1214 - val_loss: 3.9816e-04 - val_mean_absolute_error: 0.0163
# Epoch 69/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0336 - mean_absolute_error: 0.1166 - val_loss: 0.0023 - val_mean_absolute_error: 0.0450
# Epoch 70/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0334 - mean_absolute_error: 0.1188 - val_loss: 0.0019 - val_mean_absolute_error: 0.0404
# Epoch 71/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0316 - mean_absolute_error: 0.1185 - val_loss: 4.8053e-04 - val_mean_absolute_error: 0.0170
# Epoch 72/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0334 - mean_absolute_error: 0.1166 - val_loss: 0.0059 - val_mean_absolute_error: 0.0753
# Epoch 73/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0308 - mean_absolute_error: 0.1076 - val_loss: 2.4011e-04 - val_mean_absolute_error: 0.0106
# Epoch 74/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0312 - mean_absolute_error: 0.1125 - val_loss: 0.0031 - val_mean_absolute_error: 0.0533
# Epoch 75/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0303 - mean_absolute_error: 0.1125 - val_loss: 0.0025 - val_mean_absolute_error: 0.0479
# Epoch 76/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0330 - mean_absolute_error: 0.1155 - val_loss: 0.0036 - val_mean_absolute_error: 0.0579
# Epoch 77/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0332 - mean_absolute_error: 0.1178 - val_loss: 0.0055 - val_mean_absolute_error: 0.0727
# Epoch 78/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0272 - mean_absolute_error: 0.1041 - val_loss: 0.0060 - val_mean_absolute_error: 0.0759
# Epoch 79/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0290 - mean_absolute_error: 0.1080 - val_loss: 0.0064 - val_mean_absolute_error: 0.0783
# Epoch 80/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0299 - mean_absolute_error: 0.1092 - val_loss: 0.0091 - val_mean_absolute_error: 0.0941
# Epoch 81/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0300 - mean_absolute_error: 0.1119 - val_loss: 0.0063 - val_mean_absolute_error: 0.0775
# Epoch 82/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0340 - mean_absolute_error: 0.1200 - val_loss: 0.0083 - val_mean_absolute_error: 0.0900
# Epoch 83/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0273 - mean_absolute_error: 0.1042 - val_loss: 0.0042 - val_mean_absolute_error: 0.0630
# Epoch 84/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0327 - mean_absolute_error: 0.1105 - val_loss: 0.0012 - val_mean_absolute_error: 0.0311
# Epoch 85/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0290 - mean_absolute_error: 0.1079 - val_loss: 0.0048 - val_mean_absolute_error: 0.0676
# Epoch 86/250
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0282 - mean_absolute_error: 0.1104 - val_loss: 0.0055 - val_mean_absolute_error: 0.0727
# Epoch 87/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0326 - mean_absolute_error: 0.1174 - val_loss: 0.0032 - val_mean_absolute_error: 0.0546
# Epoch 88/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0309 - mean_absolute_error: 0.1146 - val_loss: 0.0012 - val_mean_absolute_error: 0.0306
# Epoch 89/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0275 - mean_absolute_error: 0.1080 - val_loss: 0.0043 - val_mean_absolute_error: 0.0634
# Epoch 90/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0277 - mean_absolute_error: 0.1099 - val_loss: 0.0145 - val_mean_absolute_error: 0.1194
# Epoch 91/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0288 - mean_absolute_error: 0.1087 - val_loss: 0.0101 - val_mean_absolute_error: 0.0995
# Epoch 92/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0266 - mean_absolute_error: 0.1067 - val_loss: 6.3062e-04 - val_mean_absolute_error: 0.0208
# Epoch 93/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0266 - mean_absolute_error: 0.1034 - val_loss: 0.0104 - val_mean_absolute_error: 0.1007
# Epoch 94/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0273 - mean_absolute_error: 0.1036 - val_loss: 0.0083 - val_mean_absolute_error: 0.0896
# Epoch 95/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0242 - mean_absolute_error: 0.0988 - val_loss: 0.0097 - val_mean_absolute_error: 0.0972
# Epoch 96/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0258 - mean_absolute_error: 0.1062 - val_loss: 0.0028 - val_mean_absolute_error: 0.0506
# Epoch 97/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0299 - mean_absolute_error: 0.1092 - val_loss: 0.0123 - val_mean_absolute_error: 0.1096
# Epoch 98/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0246 - mean_absolute_error: 0.1008 - val_loss: 5.4433e-04 - val_mean_absolute_error: 0.0187
# Epoch 99/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0278 - mean_absolute_error: 0.1116 - val_loss: 0.0077 - val_mean_absolute_error: 0.0864
# Epoch 100/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0256 - mean_absolute_error: 0.0991 - val_loss: 0.0169 - val_mean_absolute_error: 0.1291
# Epoch 101/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0272 - mean_absolute_error: 0.1105 - val_loss: 0.0166 - val_mean_absolute_error: 0.1279
# Epoch 102/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0263 - mean_absolute_error: 0.1052 - val_loss: 0.0100 - val_mean_absolute_error: 0.0989
# Epoch 103/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0245 - mean_absolute_error: 0.1016 - val_loss: 0.0070 - val_mean_absolute_error: 0.0821
# Epoch 104/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0249 - mean_absolute_error: 0.1001 - val_loss: 0.0053 - val_mean_absolute_error: 0.0713
# Epoch 105/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0231 - mean_absolute_error: 0.1008 - val_loss: 4.3169e-04 - val_mean_absolute_error: 0.0158
# Epoch 106/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0236 - mean_absolute_error: 0.1031 - val_loss: 0.0037 - val_mean_absolute_error: 0.0591
# Epoch 107/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0238 - mean_absolute_error: 0.1047 - val_loss: 0.0048 - val_mean_absolute_error: 0.0677
# Epoch 108/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0267 - mean_absolute_error: 0.1088 - val_loss: 2.3375e-04 - val_mean_absolute_error: 0.0100
# Epoch 109/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0248 - mean_absolute_error: 0.1040 - val_loss: 0.0068 - val_mean_absolute_error: 0.0808
# Epoch 110/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0244 - mean_absolute_error: 0.1051 - val_loss: 6.6127e-04 - val_mean_absolute_error: 0.0214
# Epoch 111/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0234 - mean_absolute_error: 0.0915 - val_loss: 0.0022 - val_mean_absolute_error: 0.0447
# Epoch 112/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0234 - mean_absolute_error: 0.1034 - val_loss: 0.0054 - val_mean_absolute_error: 0.0715
# Epoch 113/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0235 - mean_absolute_error: 0.1008 - val_loss: 8.2903e-04 - val_mean_absolute_error: 0.0248
# Epoch 114/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0245 - mean_absolute_error: 0.1065 - val_loss: 0.0055 - val_mean_absolute_error: 0.0725
# Epoch 115/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0242 - mean_absolute_error: 0.1036 - val_loss: 2.4969e-04 - val_mean_absolute_error: 0.0106
# Epoch 116/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0237 - mean_absolute_error: 0.0969 - val_loss: 0.0115 - val_mean_absolute_error: 0.1059
# Epoch 117/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0234 - mean_absolute_error: 0.0974 - val_loss: 0.0033 - val_mean_absolute_error: 0.0551
# Epoch 118/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0250 - mean_absolute_error: 0.1015 - val_loss: 8.3733e-04 - val_mean_absolute_error: 0.0248
# Epoch 119/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0279 - mean_absolute_error: 0.1056 - val_loss: 5.6109e-04 - val_mean_absolute_error: 0.0191
# Epoch 120/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0211 - mean_absolute_error: 0.0974 - val_loss: 0.0032 - val_mean_absolute_error: 0.0547
# Epoch 121/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0220 - mean_absolute_error: 0.0996 - val_loss: 0.0010 - val_mean_absolute_error: 0.0282
# Epoch 122/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0199 - mean_absolute_error: 0.0882 - val_loss: 0.0120 - val_mean_absolute_error: 0.1084
# Epoch 123/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0226 - mean_absolute_error: 0.1044 - val_loss: 0.0018 - val_mean_absolute_error: 0.0398
# Epoch 124/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0211 - mean_absolute_error: 0.0930 - val_loss: 0.0040 - val_mean_absolute_error: 0.0613
# Epoch 125/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0214 - mean_absolute_error: 0.0906 - val_loss: 0.0235 - val_mean_absolute_error: 0.1523
# Epoch 126/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0197 - mean_absolute_error: 0.0953 - val_loss: 4.4675e-04 - val_mean_absolute_error: 0.0164
# Epoch 127/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0209 - mean_absolute_error: 0.0930 - val_loss: 0.0022 - val_mean_absolute_error: 0.0440
# Epoch 128/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0228 - mean_absolute_error: 0.1011 - val_loss: 6.2823e-04 - val_mean_absolute_error: 0.0207
# Epoch 129/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0200 - mean_absolute_error: 0.0950 - val_loss: 0.0051 - val_mean_absolute_error: 0.0699
# Epoch 130/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0175 - mean_absolute_error: 0.0868 - val_loss: 6.1488e-04 - val_mean_absolute_error: 0.0226
# Epoch 131/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0203 - mean_absolute_error: 0.0989 - val_loss: 0.0012 - val_mean_absolute_error: 0.0313
# Epoch 132/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0193 - mean_absolute_error: 0.0916 - val_loss: 2.4699e-04 - val_mean_absolute_error: 0.0104
# Epoch 133/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0219 - mean_absolute_error: 0.1002 - val_loss: 2.5736e-04 - val_mean_absolute_error: 0.0107
# Epoch 134/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0191 - mean_absolute_error: 0.0886 - val_loss: 0.0056 - val_mean_absolute_error: 0.0732
# Epoch 135/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0224 - mean_absolute_error: 0.0978 - val_loss: 0.0166 - val_mean_absolute_error: 0.1276
# Epoch 136/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0157 - mean_absolute_error: 0.0877 - val_loss: 0.0032 - val_mean_absolute_error: 0.0541
# Epoch 137/250
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0201 - mean_absolute_error: 0.0963 - val_loss: 0.0032 - val_mean_absolute_error: 0.0544
# Epoch 138/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0182 - mean_absolute_error: 0.0922 - val_loss: 0.0010 - val_mean_absolute_error: 0.0280
# Epoch 139/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0207 - mean_absolute_error: 0.0921 - val_loss: 6.6639e-04 - val_mean_absolute_error: 0.0216
# Epoch 140/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0182 - mean_absolute_error: 0.0876 - val_loss: 0.0028 - val_mean_absolute_error: 0.0503
# Epoch 141/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0207 - mean_absolute_error: 0.0920 - val_loss: 7.0821e-04 - val_mean_absolute_error: 0.0224
# Epoch 142/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0191 - mean_absolute_error: 0.0953 - val_loss: 0.0025 - val_mean_absolute_error: 0.0477
# Epoch 143/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0193 - mean_absolute_error: 0.0904 - val_loss: 0.0041 - val_mean_absolute_error: 0.0620
# Epoch 144/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0190 - mean_absolute_error: 0.0819 - val_loss: 0.0083 - val_mean_absolute_error: 0.0899
# Epoch 145/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0179 - mean_absolute_error: 0.0855 - val_loss: 2.5910e-04 - val_mean_absolute_error: 0.0110
# Epoch 146/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0187 - mean_absolute_error: 0.0912 - val_loss: 2.4789e-04 - val_mean_absolute_error: 0.0103
# Epoch 147/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0221 - mean_absolute_error: 0.0923 - val_loss: 0.0034 - val_mean_absolute_error: 0.0562
# Epoch 148/250
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0165 - mean_absolute_error: 0.0906 - val_loss: 0.0018 - val_mean_absolute_error: 0.0392

# %% [markdown]
# ##  Predicción

# %% [markdown]
# Verifiquemos inicialmente qué tan bien se genera la predicción sobre cada dato de prueba en `X_test`:

# %%
# Predicción (1 muestra, single-step)
y_pred = [y[0] for y in modelo.predict(X_test)]
y_pred = np.array(y_pred)
print(X_test.shape)
print(len(y_pred))
# Out:
# 1/1 [==============================] - 0s 170ms/step
# (22, 14, 1)
# 22

# %%
# Predicciones en la escala original
y_test_inv = scaler.inverse_transform(Y_test)

y_pred_inv = y_pred.reshape(-1,1)
y_pred_inv = scaler.inverse_transform(y_pred_inv)

plt.figure(figsize=(12,4))
plt.plot(y_test_inv[0:500],color='blue',label='test')
plt.plot(y_pred_inv[0:500],color='orange',label='predicción')
plt.legend();

# %%
# Gráfica del error absoluto
plt.figure(figsize=(12,4))
plt.plot(np.abs(y_test_inv-y_pred_inv), color='red');
plt.ylabel('Error absoluto (en Watts)');

# %%
modelo.save('modeloLSTM6.h5')  # Guarda el modelo en formato HDF5
# Out:
# /usr/lib/python3/dist-packages/keras/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# Ahora haremos predicción *multi-step*: en lugar de predecir un sólo dato vamos a predecir una secuencia completa:

# %%
# Tomar la primera parte de X_test como punto de inicio
x_pred = X_test[0,:,:].reshape(1,LONG_SEC,1)

# Iterativamente predecir y201 = pred(x1,x2,...,x200),
# y202 = pred(x2, x3, x4,..., x200, y201), etc...

N_preds = 100
y_preds = []    

for i in range(N_preds):

  pred = modelo.predict(x_pred)
  y_preds.append(pred[0])

  x_pred = np.append(x_pred,pred[0])

  x_pred = np.delete(x_pred,0)

  x_pred = np.reshape(x_pred,(1,LONG_SEC,1))
# Out:
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step

# %%
# Regresamos las predicciones en la escala original
y_preds = np.array(y_preds).reshape(-1,1)
y_preds = scaler.inverse_transform(y_preds)

# Comparación gráfica con el set de prueba original
plt.figure(figsize=(12,4))
plt.plot(y_test_inv[0:N_preds],color='blue',label='test')
plt.plot(y_preds[0:N_preds],color='orange',label='predicción multi-step')
plt.legend();

# %%
HRS = 10
plt.figure(figsize=(12,4))
plt.plot(range(1,HRS+1),y_test_inv[0:HRS],color='blue',label='test')
plt.plot(range(1,HRS+1),y_preds[0:HRS],color='orange',label='predicción multi-step')
plt.legend();
